# %% [markdown]
# ## 練習時間
# 相信大家對回歸問題及分類問題都有初步的了解。今天的作業希望大家搜尋有關 multi-label 的案例問題。下圖是電影 "奇異博士" 的分類。可以看到同時有 "Action", "Adventure", "Fantasy" 的類別存在，代表這是個多標籤的問題。

# %% [markdown]
# ![image](https://cdn-images-1.medium.com/max/1000/1*r0gYXMSQf5VhdMyl2bRDyg.png)

# %% [markdown]
# ## 請搜尋目標為多標籤問題 (Multi-label) 的機器學習案例，了解其資料來源、目標以及評估指標為何
# ## Hint: 服飾
#
# Answer :
#
# 研究目標 : 利用Multi-label model進行音樂情感辨識，進而判斷音樂複合的類型(ex. 快樂、憤怒、悲傷)
#
# 資料來源 : 此研究蒐集了593首歌，音檔來自七種曲風類型: Classical, Reggae,
# Rock, Pop, Hip-Hop, Techno and Jazz、來自233張唱片，每張取3首音樂。再由專業的音樂學院學生經兩者特性(節奏特性、音色特點)將其分成六類。
#
# 評估指標 :  使用 Mean accuracy score判定準確度。
#
# 論文出處 : http://lpis.csd.auth.gr/publications/tsoumakas-ismir08.pdf

# %%
import cv2
from matplotlib import pyplot as plt
print('The accuracy result shows below')
img = cv2.imread('Accuracy_score.png')
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
# Out:
# The accuracy result shows below

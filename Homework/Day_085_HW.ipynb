# %% [markdown]
# ## Work
# 1. 試改變 monitor "Validation Accuracy" 並比較結果
# 2. 調整 earlystop 的等待次數至 10, 25 並比較結果

# %%
import os
import keras
import matplotlib.pyplot as plt
# %matplotlib inline


# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256,128]):
    input_layer = keras.layers.Input(input_shape)

    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x= keras.layers.Dense(units=n_units,
                                  activation='relu',
                                  name='hidden_layer'+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units,
                                   activation='relu',
                                   name='hidden_layer'+str(i+1))(x)
            x = BatchNormalization()(x)
    out = keras.layers.Dense(units=output_units,
                             activation='softmax',
                             name='output')(x)
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LR = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

PATIENCE = [10, 25]

# %%
# 載入 Callbacks
"""Code Here
設定 callbacks: Earlystop
"""
from keras.callbacks import EarlyStopping
import keras.backend as K
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
results = {}
for i, patience in enumerate(PATIENCE):
    K.clear_session()
    print('Numbers of exp: %i, with patience: %s' % (i, patience))
    earlystop = EarlyStopping(monitor='val_accuracy',
                            patience=patience,
                            verbose=1)
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()

    optimizer = keras.optimizers.SGD(lr=LR, nesterov=True, momentum=MOMENTUM)
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=optimizer)

    model.fit(x_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(x_test, y_test), shuffle=True, callbacks=[earlystop])
    
    exp_name_tag=('exp-%s' % (i))
    results[exp_name_tag] = {'train-loss' : model.history.history['loss'],
                             'valid-loss' : model.history.history['val_loss'],
                             'train-acc' : model.history.history['accuracy'],
                             'valid-acc' : model.history.history['val_accuracy']}
# Out:
# Numbers of exp: 0, with patience: 10
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 7s 143us/step - loss: 2.2139 - accuracy: 0.2677 - val_loss: 2.1744 - val_accuracy: 0.1788
# Epoch 2/50
# 50000/50000 [==============================] - 7s 141us/step - loss: 1.7414 - accuracy: 0.3935 - val_loss: 1.9766 - val_accuracy: 0.2928
# Epoch 3/50
# 50000/50000 [==============================] - 7s 140us/step - loss: 1.6197 - accuracy: 0.4327 - val_loss: 1.8092 - val_accuracy: 0.3742
# Epoch 4/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 1.5490 - accuracy: 0.4575 - val_loss: 1.7108 - val_accuracy: 0.4144
# Epoch 5/50
# 50000/50000 [==============================] - 7s 131us/step - loss: 1.4957 - accuracy: 0.4771 - val_loss: 1.6339 - val_accuracy: 0.4331
# Epoch 6/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.4518 - accuracy: 0.4929 - val_loss: 1.5853 - val_accuracy: 0.4426
# Epoch 7/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 1.4133 - accuracy: 0.5083 - val_loss: 1.5482 - val_accuracy: 0.4560
# Epoch 8/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 1.3793 - accuracy: 0.5202 - val_loss: 1.5245 - val_accuracy: 0.4606
# Epoch 9/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.3463 - accuracy: 0.5313 - val_loss: 1.5076 - val_accuracy: 0.4621
# Epoch 10/50
# 50000/50000 [==============================] - 7s 131us/step - loss: 1.3157 - accuracy: 0.5428 - val_loss: 1.4966 - val_accuracy: 0.4704
# Epoch 11/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 1.2886 - accuracy: 0.5533 - val_loss: 1.4891 - val_accuracy: 0.4760
# Epoch 12/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.2618 - accuracy: 0.5630 - val_loss: 1.4850 - val_accuracy: 0.4755
# Epoch 13/50
# 50000/50000 [==============================] - 7s 131us/step - loss: 1.2366 - accuracy: 0.5709 - val_loss: 1.4657 - val_accuracy: 0.4806
# Epoch 14/50
# 50000/50000 [==============================] - 7s 131us/step - loss: 1.2108 - accuracy: 0.5795 - val_loss: 1.4784 - val_accuracy: 0.4728
# Epoch 15/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 1.1861 - accuracy: 0.5910 - val_loss: 1.4649 - val_accuracy: 0.4808
# Epoch 16/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 1.1613 - accuracy: 0.5999 - val_loss: 1.4601 - val_accuracy: 0.4839
# Epoch 17/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.1386 - accuracy: 0.6078 - val_loss: 1.4694 - val_accuracy: 0.4860
# Epoch 18/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.1177 - accuracy: 0.6150 - val_loss: 1.4540 - val_accuracy: 0.4899
# Epoch 19/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 1.0923 - accuracy: 0.6259 - val_loss: 1.4636 - val_accuracy: 0.4885
# Epoch 20/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 1.0713 - accuracy: 0.6327 - val_loss: 1.4510 - val_accuracy: 0.4954
# Epoch 21/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 1.0514 - accuracy: 0.6399 - val_loss: 1.4592 - val_accuracy: 0.4907
# Epoch 22/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.0286 - accuracy: 0.6485 - val_loss: 1.4522 - val_accuracy: 0.4957
# Epoch 23/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 1.0073 - accuracy: 0.6574 - val_loss: 1.4517 - val_accuracy: 0.4957
# Epoch 24/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.9873 - accuracy: 0.6654 - val_loss: 1.4594 - val_accuracy: 0.4924
# Epoch 25/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.9653 - accuracy: 0.6737 - val_loss: 1.4636 - val_accuracy: 0.4916
# Epoch 26/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.9433 - accuracy: 0.6814 - val_loss: 1.4638 - val_accuracy: 0.4952
# Epoch 27/50
# 50000/50000 [==============================] - 7s 131us/step - loss: 0.9250 - accuracy: 0.6897 - val_loss: 1.4696 - val_accuracy: 0.4928
# Epoch 28/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.9059 - accuracy: 0.6956 - val_loss: 1.4724 - val_accuracy: 0.4950
# Epoch 29/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.8849 - accuracy: 0.7047 - val_loss: 1.4828 - val_accuracy: 0.4974
# Epoch 30/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 0.8642 - accuracy: 0.7117 - val_loss: 1.4812 - val_accuracy: 0.4940
# Epoch 31/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 0.8446 - accuracy: 0.7214 - val_loss: 1.4908 - val_accuracy: 0.4946
# Epoch 32/50
# 50000/50000 [==============================] - 7s 138us/step - loss: 0.8251 - accuracy: 0.7269 - val_loss: 1.4998 - val_accuracy: 0.4956
# Epoch 33/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.8050 - accuracy: 0.7369 - val_loss: 1.4976 - val_accuracy: 0.4978
# Epoch 34/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 0.7866 - accuracy: 0.7440 - val_loss: 1.5068 - val_accuracy: 0.4920
# Epoch 35/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 0.7657 - accuracy: 0.7514 - val_loss: 1.5313 - val_accuracy: 0.4899
# Epoch 36/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.7453 - accuracy: 0.7590 - val_loss: 1.5234 - val_accuracy: 0.4919
# Epoch 37/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 0.7277 - accuracy: 0.7666 - val_loss: 1.5442 - val_accuracy: 0.4872
# Epoch 38/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.7106 - accuracy: 0.7742 - val_loss: 1.5423 - val_accuracy: 0.4912
# Epoch 39/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 0.6904 - accuracy: 0.7831 - val_loss: 1.5410 - val_accuracy: 0.4916
# Epoch 40/50
# 50000/50000 [==============================] - 7s 137us/step - loss: 0.6721 - accuracy: 0.7897 - val_loss: 1.5528 - val_accuracy: 0.4929
# Epoch 41/50
# 50000/50000 [==============================] - 7s 137us/step - loss: 0.6534 - accuracy: 0.7962 - val_loss: 1.5781 - val_accuracy: 0.4856
# Epoch 42/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 0.6356 - accuracy: 0.8037 - val_loss: 1.5846 - val_accuracy: 0.4926
# Epoch 43/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 0.6195 - accuracy: 0.8111 - val_loss: 1.5877 - val_accuracy: 0.4901
# Epoch 00043: early stopping
# Numbers of exp: 1, with patience: 25
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 7s 144us/step - loss: 2.2053 - accuracy: 0.2693 - val_loss: 2.1310 - val_accuracy: 0.2010
# Epoch 2/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 1.7496 - accuracy: 0.3934 - val_loss: 1.9978 - val_accuracy: 0.2775
# Epoch 3/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 1.6269 - accuracy: 0.4321 - val_loss: 1.8519 - val_accuracy: 0.3560
# Epoch 4/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.5556 - accuracy: 0.4570 - val_loss: 1.7337 - val_accuracy: 0.4001
# Epoch 5/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.5009 - accuracy: 0.4769 - val_loss: 1.6673 - val_accuracy: 0.4125
# Epoch 6/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.4556 - accuracy: 0.4928 - val_loss: 1.6079 - val_accuracy: 0.4329
# Epoch 7/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.4177 - accuracy: 0.5064 - val_loss: 1.5681 - val_accuracy: 0.4478
# Epoch 8/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.3808 - accuracy: 0.5202 - val_loss: 1.5375 - val_accuracy: 0.4541
# Epoch 9/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.3496 - accuracy: 0.5315 - val_loss: 1.5192 - val_accuracy: 0.4607
# Epoch 10/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.3204 - accuracy: 0.5419 - val_loss: 1.5078 - val_accuracy: 0.4653
# Epoch 11/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.2909 - accuracy: 0.5509 - val_loss: 1.4941 - val_accuracy: 0.4719
# Epoch 12/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 1.2661 - accuracy: 0.5588 - val_loss: 1.4892 - val_accuracy: 0.4706
# Epoch 13/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.2390 - accuracy: 0.5730 - val_loss: 1.4804 - val_accuracy: 0.4765
# Epoch 14/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 1.2137 - accuracy: 0.5807 - val_loss: 1.4749 - val_accuracy: 0.4825
# Epoch 15/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.1907 - accuracy: 0.5897 - val_loss: 1.4749 - val_accuracy: 0.4840
# Epoch 16/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.1679 - accuracy: 0.5988 - val_loss: 1.4868 - val_accuracy: 0.4786
# Epoch 17/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.1447 - accuracy: 0.6082 - val_loss: 1.4772 - val_accuracy: 0.4847
# Epoch 18/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.1223 - accuracy: 0.6160 - val_loss: 1.4626 - val_accuracy: 0.4892
# Epoch 19/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 1.0992 - accuracy: 0.6232 - val_loss: 1.4775 - val_accuracy: 0.4823
# Epoch 20/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 1.0783 - accuracy: 0.6330 - val_loss: 1.4627 - val_accuracy: 0.4888
# Epoch 21/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.0542 - accuracy: 0.6420 - val_loss: 1.4659 - val_accuracy: 0.4902
# Epoch 22/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.0343 - accuracy: 0.6493 - val_loss: 1.4573 - val_accuracy: 0.4935
# Epoch 23/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.0142 - accuracy: 0.6551 - val_loss: 1.4615 - val_accuracy: 0.4961
# Epoch 24/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 0.9920 - accuracy: 0.6675 - val_loss: 1.4711 - val_accuracy: 0.4942
# Epoch 25/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.9728 - accuracy: 0.6739 - val_loss: 1.4654 - val_accuracy: 0.4977
# Epoch 26/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.9510 - accuracy: 0.6812 - val_loss: 1.4736 - val_accuracy: 0.4957
# Epoch 27/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.9319 - accuracy: 0.6909 - val_loss: 1.4691 - val_accuracy: 0.4987
# Epoch 28/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.9121 - accuracy: 0.6973 - val_loss: 1.4722 - val_accuracy: 0.5005
# Epoch 29/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 0.8905 - accuracy: 0.7076 - val_loss: 1.4859 - val_accuracy: 0.4978
# Epoch 30/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.8719 - accuracy: 0.7137 - val_loss: 1.4935 - val_accuracy: 0.4987
# Epoch 31/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.8510 - accuracy: 0.7219 - val_loss: 1.4961 - val_accuracy: 0.4996
# Epoch 32/50
# 50000/50000 [==============================] - 7s 147us/step - loss: 0.8334 - accuracy: 0.7287 - val_loss: 1.4980 - val_accuracy: 0.4949
# Epoch 33/50
# 50000/50000 [==============================] - 7s 141us/step - loss: 0.8137 - accuracy: 0.7365 - val_loss: 1.5121 - val_accuracy: 0.4933
# Epoch 34/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.7968 - accuracy: 0.7434 - val_loss: 1.5173 - val_accuracy: 0.4962
# Epoch 35/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 0.7754 - accuracy: 0.7506 - val_loss: 1.5138 - val_accuracy: 0.5002
# Epoch 36/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.7574 - accuracy: 0.7591 - val_loss: 1.5364 - val_accuracy: 0.4966
# Epoch 37/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 0.7388 - accuracy: 0.7662 - val_loss: 1.5459 - val_accuracy: 0.4918
# Epoch 38/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.7194 - accuracy: 0.7742 - val_loss: 1.5618 - val_accuracy: 0.4878
# Epoch 39/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.7011 - accuracy: 0.7810 - val_loss: 1.5740 - val_accuracy: 0.4901
# Epoch 40/50
# 50000/50000 [==============================] - 7s 141us/step - loss: 0.6838 - accuracy: 0.7873 - val_loss: 1.5793 - val_accuracy: 0.4888
# Epoch 41/50
# 50000/50000 [==============================] - 7s 141us/step - loss: 0.6644 - accuracy: 0.7954 - val_loss: 1.5744 - val_accuracy: 0.4977
# Epoch 42/50
# 50000/50000 [==============================] - 7s 139us/step - loss: 0.6455 - accuracy: 0.8012 - val_loss: 1.5861 - val_accuracy: 0.4930
# Epoch 43/50
# 50000/50000 [==============================] - 7s 139us/step - loss: 0.6257 - accuracy: 0.8110 - val_loss: 1.6033 - val_accuracy: 0.4936
# Epoch 44/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.6104 - accuracy: 0.8165 - val_loss: 1.6242 - val_accuracy: 0.4925
# Epoch 45/50
# 50000/50000 [==============================] - 7s 137us/step - loss: 0.5923 - accuracy: 0.8236 - val_loss: 1.6014 - val_accuracy: 0.5012
# Epoch 46/50
# 50000/50000 [==============================] - 7s 139us/step - loss: 0.5746 - accuracy: 0.8301 - val_loss: 1.6307 - val_accuracy: 0.4929
# Epoch 47/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.5593 - accuracy: 0.8353 - val_loss: 1.6445 - val_accuracy: 0.4923
# Epoch 48/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 0.5416 - accuracy: 0.8426 - val_loss: 1.6527 - val_accuracy: 0.4958
# Epoch 49/50
# 50000/50000 [==============================] - 7s 142us/step - loss: 0.5257 - accuracy: 0.8489 - val_loss: 1.6665 - val_accuracy: 0.4996
# Epoch 50/50
# 50000/50000 [==============================] - 7s 138us/step - loss: 0.5089 - accuracy: 0.8558 - val_loss: 1.6880 - val_accuracy: 0.4880

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
import matplotlib.cm as mplcm
import matplotlib.colors as colors

N_COLORS = 20

cm = plt.get_cmap('gist_rainbow')
cNorm = colors.Normalize(vmin=0, vmax=N_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(N_COLORS)]
plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])), results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])), results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title('Loss')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])), results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])), results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title('Accuracy')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
results.keys()
# Out:
# dict_keys(['exp-0', 'exp-1'])

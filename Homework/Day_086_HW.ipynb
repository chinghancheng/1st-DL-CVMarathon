# %% [markdown]
# ## Work
# 1. 試比較 save_best_only 與否的差異
# 2. 請僅存入將 save_weights_only 設定為 True, 並嘗試 reset ipynb 並將模型與權重重新建回並預測 x_test

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)

    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units,
                                   activation='relu',
                                   name='hidden_layer'+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units,
                                   activation='relu',
                                   name='hidden_layer'+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation='softmax', name='output')(x)
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
"""Code Here
設定 callbacks: model checkpoint
"""
from keras.callbacks import ModelCheckpoint
model_ckpt = ModelCheckpoint(filepath='./tmp.h5',
                             monitor='val_loss',
                             save_best_only=True)
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=optimizer)

model.fit(x_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(x_test, y_test), shuffle=True, callbacks=[model_ckpt])

train_loss = model.history.history['loss']
valid_loss = model.history.history['val_loss']
train_acc = model.history.history['accuracy']
valid_acc = model.history.history["val_accuracy"]

# Load back
model = keras.models.load_model("./tmp.h5")
loss_loadback, acc_loadback = model.evaluate(x_test, y_test)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 6s 128us/step - loss: 2.1819 - accuracy: 0.2791 - val_loss: 2.1283 - val_accuracy: 0.2016
# Epoch 2/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.7394 - accuracy: 0.3936 - val_loss: 1.9589 - val_accuracy: 0.2889
# Epoch 3/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.6152 - accuracy: 0.4346 - val_loss: 1.8023 - val_accuracy: 0.3724
# Epoch 4/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.5394 - accuracy: 0.4629 - val_loss: 1.6915 - val_accuracy: 0.4184
# Epoch 5/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.4857 - accuracy: 0.4818 - val_loss: 1.6237 - val_accuracy: 0.4398
# Epoch 6/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.4421 - accuracy: 0.4960 - val_loss: 1.5688 - val_accuracy: 0.4500
# Epoch 7/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.4028 - accuracy: 0.5110 - val_loss: 1.5390 - val_accuracy: 0.4547
# Epoch 8/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.3671 - accuracy: 0.5224 - val_loss: 1.5194 - val_accuracy: 0.4672
# Epoch 9/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.3376 - accuracy: 0.5352 - val_loss: 1.4979 - val_accuracy: 0.4730
# Epoch 10/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.3075 - accuracy: 0.5453 - val_loss: 1.4889 - val_accuracy: 0.4764
# Epoch 11/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.2811 - accuracy: 0.5555 - val_loss: 1.4805 - val_accuracy: 0.4800
# Epoch 12/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.2558 - accuracy: 0.5645 - val_loss: 1.4647 - val_accuracy: 0.4821
# Epoch 13/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.2306 - accuracy: 0.5758 - val_loss: 1.4642 - val_accuracy: 0.4849
# Epoch 14/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.2044 - accuracy: 0.5838 - val_loss: 1.4610 - val_accuracy: 0.4892
# Epoch 15/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.1836 - accuracy: 0.5913 - val_loss: 1.4519 - val_accuracy: 0.4908
# Epoch 16/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.1606 - accuracy: 0.6009 - val_loss: 1.4616 - val_accuracy: 0.4885
# Epoch 17/50
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.1374 - accuracy: 0.6099 - val_loss: 1.4586 - val_accuracy: 0.4911
# Epoch 18/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.1173 - accuracy: 0.6172 - val_loss: 1.4477 - val_accuracy: 0.4960
# Epoch 19/50
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.0942 - accuracy: 0.6258 - val_loss: 1.4596 - val_accuracy: 0.4916
# Epoch 20/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.0735 - accuracy: 0.6345 - val_loss: 1.4523 - val_accuracy: 0.4968
# Epoch 21/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.0519 - accuracy: 0.6409 - val_loss: 1.4568 - val_accuracy: 0.4926
# Epoch 22/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.0308 - accuracy: 0.6504 - val_loss: 1.4675 - val_accuracy: 0.4906
# Epoch 23/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.0107 - accuracy: 0.6585 - val_loss: 1.4559 - val_accuracy: 0.4976
# Epoch 24/50
# 50000/50000 [==============================] - 6s 112us/step - loss: 0.9911 - accuracy: 0.6659 - val_loss: 1.4611 - val_accuracy: 0.4937
# Epoch 25/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.9698 - accuracy: 0.6739 - val_loss: 1.4616 - val_accuracy: 0.4977
# Epoch 26/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.9516 - accuracy: 0.6801 - val_loss: 1.4738 - val_accuracy: 0.4972
# Epoch 27/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 0.9322 - accuracy: 0.6879 - val_loss: 1.4791 - val_accuracy: 0.4943
# Epoch 28/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 0.9119 - accuracy: 0.6951 - val_loss: 1.4771 - val_accuracy: 0.4982
# Epoch 29/50
# 50000/50000 [==============================] - 6s 114us/step - loss: 0.8930 - accuracy: 0.7033 - val_loss: 1.4746 - val_accuracy: 0.4979
# Epoch 30/50
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.8723 - accuracy: 0.7134 - val_loss: 1.4935 - val_accuracy: 0.4924
# Epoch 31/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.8562 - accuracy: 0.7173 - val_loss: 1.5025 - val_accuracy: 0.4920
# Epoch 32/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.8351 - accuracy: 0.7266 - val_loss: 1.4940 - val_accuracy: 0.4909
# Epoch 33/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.8169 - accuracy: 0.7337 - val_loss: 1.5087 - val_accuracy: 0.4930
# Epoch 34/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.7964 - accuracy: 0.7416 - val_loss: 1.5155 - val_accuracy: 0.4963
# Epoch 35/50
# 50000/50000 [==============================] - 6s 111us/step - loss: 0.7801 - accuracy: 0.7485 - val_loss: 1.5332 - val_accuracy: 0.4976
# Epoch 36/50
# 50000/50000 [==============================] - 6s 114us/step - loss: 0.7598 - accuracy: 0.7552 - val_loss: 1.5399 - val_accuracy: 0.4944
# Epoch 37/50
# 50000/50000 [==============================] - 6s 113us/step - loss: 0.7404 - accuracy: 0.7653 - val_loss: 1.5495 - val_accuracy: 0.4937
# Epoch 38/50
# 50000/50000 [==============================] - 6s 117us/step - loss: 0.7215 - accuracy: 0.7705 - val_loss: 1.5396 - val_accuracy: 0.4942
# Epoch 39/50
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.7033 - accuracy: 0.7789 - val_loss: 1.5675 - val_accuracy: 0.4903
# Epoch 40/50
# 50000/50000 [==============================] - 6s 114us/step - loss: 0.6845 - accuracy: 0.7850 - val_loss: 1.5522 - val_accuracy: 0.4956
# Epoch 41/50
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.6663 - accuracy: 0.7923 - val_loss: 1.5837 - val_accuracy: 0.4876
# Epoch 42/50
# 50000/50000 [==============================] - 6s 116us/step - loss: 0.6478 - accuracy: 0.8002 - val_loss: 1.5873 - val_accuracy: 0.4888
# Epoch 43/50
# 50000/50000 [==============================] - 6s 113us/step - loss: 0.6299 - accuracy: 0.8082 - val_loss: 1.6277 - val_accuracy: 0.4852
# Epoch 44/50
# 50000/50000 [==============================] - 6s 113us/step - loss: 0.6142 - accuracy: 0.8138 - val_loss: 1.6040 - val_accuracy: 0.4913
# Epoch 45/50
# 50000/50000 [==============================] - 6s 110us/step - loss: 0.5955 - accuracy: 0.8208 - val_loss: 1.6342 - val_accuracy: 0.4890
# Epoch 46/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 0.5805 - accuracy: 0.8254 - val_loss: 1.6325 - val_accuracy: 0.4912
# Epoch 47/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 0.5625 - accuracy: 0.8347 - val_loss: 1.6678 - val_accuracy: 0.4804
# Epoch 48/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 0.5461 - accuracy: 0.8404 - val_loss: 1.7133 - val_accuracy: 0.4863
# Epoch 49/50
# 50000/50000 [==============================] - 6s 111us/step - loss: 0.5287 - accuracy: 0.8473 - val_loss: 1.6675 - val_accuracy: 0.4901
# Epoch 50/50
# 50000/50000 [==============================] - 6s 111us/step - loss: 0.5112 - accuracy: 0.8551 - val_loss: 1.6835 - val_accuracy: 0.4861
# 10000/10000 [==============================] - 1s 84us/step

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""

plt.plot(range(len(train_loss)), train_loss, label='train loss')
plt.plot(range(len(valid_loss)), valid_loss, label='valid loss')
plt.hlines(y=loss_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title('Loss')
plt.show()

plt.plot(range(len(train_acc)), train_acc, label='train accuracy')
plt.plot(range(len(valid_acc)), valid_acc, label='valid accuracy')
plt.hlines(y=acc_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title('Accuracy')
plt.show()

# %%
# 載入 Callbacks
"""Code Here
設定 callbacks: model checkpoint
"""
from keras.callbacks import ModelCheckpoint
model_ckpt = ModelCheckpoint(filepath='./tmp_F.h5',
                             monitor='val_loss',
                             save_best_only=False)
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=optimizer)

model.fit(x_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(x_test, y_test), shuffle=True, callbacks=[model_ckpt])

train_loss = model.history.history['loss']
valid_loss = model.history.history['val_loss']
train_acc = model.history.history['accuracy']
valid_acc = model.history.history["val_accuracy"]

# Load back
model = keras.models.load_model("./tmp_F.h5")
loss_loadback, acc_loadback = model.evaluate(x_test, y_test)
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 6s 112us/step - loss: 2.2624 - accuracy: 0.2720 - val_loss: 2.1530 - val_accuracy: 0.1711
# Epoch 2/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.7442 - accuracy: 0.3940 - val_loss: 1.9780 - val_accuracy: 0.2863
# Epoch 3/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.6134 - accuracy: 0.4381 - val_loss: 1.8335 - val_accuracy: 0.3438
# Epoch 4/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.5370 - accuracy: 0.4643 - val_loss: 1.7095 - val_accuracy: 0.4076
# Epoch 5/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.4802 - accuracy: 0.4843 - val_loss: 1.6397 - val_accuracy: 0.4212
# Epoch 6/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.4366 - accuracy: 0.4992 - val_loss: 1.5888 - val_accuracy: 0.4395
# Epoch 7/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.3976 - accuracy: 0.5147 - val_loss: 1.5496 - val_accuracy: 0.4473
# Epoch 8/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.3639 - accuracy: 0.5261 - val_loss: 1.5317 - val_accuracy: 0.4578
# Epoch 9/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.3317 - accuracy: 0.5392 - val_loss: 1.5005 - val_accuracy: 0.4635
# Epoch 10/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.3014 - accuracy: 0.5504 - val_loss: 1.5043 - val_accuracy: 0.4617
# Epoch 11/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.2749 - accuracy: 0.5590 - val_loss: 1.4924 - val_accuracy: 0.4724
# Epoch 12/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.2470 - accuracy: 0.5710 - val_loss: 1.4743 - val_accuracy: 0.4771
# Epoch 13/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.2214 - accuracy: 0.5811 - val_loss: 1.4692 - val_accuracy: 0.4782
# Epoch 14/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.1971 - accuracy: 0.5879 - val_loss: 1.4736 - val_accuracy: 0.4742
# Epoch 15/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.1734 - accuracy: 0.5975 - val_loss: 1.4597 - val_accuracy: 0.4831
# Epoch 16/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.1488 - accuracy: 0.6066 - val_loss: 1.4531 - val_accuracy: 0.4896
# Epoch 17/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.1271 - accuracy: 0.6143 - val_loss: 1.4550 - val_accuracy: 0.4806
# Epoch 18/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.1047 - accuracy: 0.6236 - val_loss: 1.4494 - val_accuracy: 0.4923
# Epoch 19/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.0836 - accuracy: 0.6311 - val_loss: 1.4488 - val_accuracy: 0.4920
# Epoch 20/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.0623 - accuracy: 0.6392 - val_loss: 1.4504 - val_accuracy: 0.4900
# Epoch 21/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.0394 - accuracy: 0.6483 - val_loss: 1.4450 - val_accuracy: 0.4900
# Epoch 22/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.0195 - accuracy: 0.6578 - val_loss: 1.4409 - val_accuracy: 0.4982
# Epoch 23/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 0.9958 - accuracy: 0.6667 - val_loss: 1.4597 - val_accuracy: 0.4902
# Epoch 24/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 0.9772 - accuracy: 0.6727 - val_loss: 1.4575 - val_accuracy: 0.4912
# Epoch 25/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.9562 - accuracy: 0.6834 - val_loss: 1.4633 - val_accuracy: 0.4894
# Epoch 26/50
# 50000/50000 [==============================] - 6s 113us/step - loss: 0.9347 - accuracy: 0.6909 - val_loss: 1.4671 - val_accuracy: 0.4889
# Epoch 27/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 0.9147 - accuracy: 0.6983 - val_loss: 1.4661 - val_accuracy: 0.4911
# Epoch 28/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 0.8948 - accuracy: 0.7069 - val_loss: 1.4695 - val_accuracy: 0.4913
# Epoch 29/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 0.8746 - accuracy: 0.7138 - val_loss: 1.4686 - val_accuracy: 0.4932
# Epoch 30/50
# 50000/50000 [==============================] - 6s 113us/step - loss: 0.8559 - accuracy: 0.7204 - val_loss: 1.4788 - val_accuracy: 0.4957
# Epoch 31/50
# 50000/50000 [==============================] - 6s 116us/step - loss: 0.8351 - accuracy: 0.7301 - val_loss: 1.4916 - val_accuracy: 0.4920
# Epoch 32/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 0.8166 - accuracy: 0.7374 - val_loss: 1.4861 - val_accuracy: 0.4884
# Epoch 33/50
# 50000/50000 [==============================] - 6s 116us/step - loss: 0.7964 - accuracy: 0.7452 - val_loss: 1.4977 - val_accuracy: 0.4880
# Epoch 34/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.7782 - accuracy: 0.7510 - val_loss: 1.5078 - val_accuracy: 0.4947
# Epoch 35/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.7582 - accuracy: 0.7591 - val_loss: 1.5116 - val_accuracy: 0.4934
# Epoch 36/50
# 50000/50000 [==============================] - 6s 119us/step - loss: 0.7388 - accuracy: 0.7676 - val_loss: 1.5077 - val_accuracy: 0.4927
# Epoch 37/50
# 50000/50000 [==============================] - 6s 114us/step - loss: 0.7220 - accuracy: 0.7735 - val_loss: 1.5321 - val_accuracy: 0.4888
# Epoch 38/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.7036 - accuracy: 0.7818 - val_loss: 1.5533 - val_accuracy: 0.4876
# Epoch 39/50
# 50000/50000 [==============================] - 6s 116us/step - loss: 0.6853 - accuracy: 0.7866 - val_loss: 1.5486 - val_accuracy: 0.4923
# Epoch 40/50
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.6669 - accuracy: 0.7943 - val_loss: 1.5501 - val_accuracy: 0.4878
# Epoch 41/50
# 50000/50000 [==============================] - 6s 119us/step - loss: 0.6480 - accuracy: 0.8008 - val_loss: 1.5549 - val_accuracy: 0.4951
# Epoch 42/50
# 50000/50000 [==============================] - 6s 116us/step - loss: 0.6294 - accuracy: 0.8102 - val_loss: 1.5817 - val_accuracy: 0.4896
# Epoch 43/50
# 50000/50000 [==============================] - 6s 118us/step - loss: 0.6132 - accuracy: 0.8151 - val_loss: 1.5752 - val_accuracy: 0.4873
# Epoch 44/50
# 50000/50000 [==============================] - 6s 117us/step - loss: 0.5936 - accuracy: 0.8230 - val_loss: 1.5892 - val_accuracy: 0.4900
# Epoch 45/50
# 50000/50000 [==============================] - 6s 121us/step - loss: 0.5774 - accuracy: 0.8292 - val_loss: 1.6137 - val_accuracy: 0.4898
# Epoch 46/50
# 50000/50000 [==============================] - 6s 120us/step - loss: 0.5588 - accuracy: 0.8372 - val_loss: 1.6257 - val_accuracy: 0.4838
# Epoch 47/50
# 50000/50000 [==============================] - 6s 119us/step - loss: 0.5430 - accuracy: 0.8432 - val_loss: 1.6279 - val_accuracy: 0.4876
# Epoch 48/50
# 50000/50000 [==============================] - 6s 118us/step - loss: 0.5252 - accuracy: 0.8523 - val_loss: 1.6363 - val_accuracy: 0.4860
# Epoch 49/50
# 50000/50000 [==============================] - 6s 118us/step - loss: 0.5089 - accuracy: 0.8571 - val_loss: 1.6523 - val_accuracy: 0.4847
# Epoch 50/50
# 50000/50000 [==============================] - 6s 117us/step - loss: 0.4919 - accuracy: 0.8639 - val_loss: 1.6695 - val_accuracy: 0.4843
# 10000/10000 [==============================] - 1s 97us/step

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""

plt.plot(range(len(train_loss)), train_loss, label='train loss')
plt.plot(range(len(valid_loss)), valid_loss, label='valid loss')
plt.hlines(y=loss_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title('Loss')
plt.show()

plt.plot(range(len(train_acc)), train_acc, label='train accuracy')
plt.plot(range(len(valid_acc)), valid_acc, label='valid accuracy')
plt.hlines(y=acc_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title('Accuracy')
plt.show()

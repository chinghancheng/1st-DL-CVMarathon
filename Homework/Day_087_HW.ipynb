# %% [markdown]
# ## Work
# 1. 請改變 reduce_lr 的 patience 和 factor 並比較不同設定下，對訓練/驗證集的影響
# 2. 請將 optimizer 換成 Adam、RMSprop 搭配 reduce_lr 並比較訓練結果

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[256, 256, 256]):
    input_layer = keras.layers.Input(input_shape)
    """Code Here
    建立你的神經網路
    """
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units,
                                   activation='relu',
                                   name='hidden_layer'+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units,
                                   activation='relu',
                                   name='hidden_layer'+str(i+1))(x)
            x = BatchNormalization()(x)

    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
LEARNING_RATE = 1e-3
EPOCHS = 25 # IF you feel too run to finish, try to make it smaller
BATCH_SIZE = 1024

# %%
# 載入 Callbacks
from keras.callbacks import ReduceLROnPlateau

optimizer_set = [keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=0.95),
                 keras.optimizers.Adam(lr=LEARNING_RATE),
                 keras.optimizers.RMSprop(lr=LEARNING_RATE)]

"""Code Here
建立實驗的比較組合
"""
reduce_lr_factor = [0.1, 0.3, 0.5, 0.8]
redice_lr_patient = [1, 3, 5, 10]

# %%
import itertools
results = {}
for i, (optim, reduce_factor, reduce_patient) in enumerate(itertools.product(optimizer_set, reduce_lr_factor, redice_lr_patient)):
    print("Numbers of exp: %i, reduce_factor: %.2f, reduce_patient: %i" % (i, reduce_factor, reduce_patient))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optim)
    
    """Code Here
    設定 reduce learning rate 的 callback function
    """
    reduce_lr = ReduceLROnPlateau(factor=0.5, 
                                  min_lr=1e-12, 
                                  monitor='val_loss', 
                                  patience=5, 
                                  verbose=1)
    
    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True,
              callbacks=[reduce_lr]
             )

    # Collect results
    exp_name_tag = ("exp-%s" % (i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["accuracy"],
                             'valid-acc': model.history.history["val_accuracy"]}
# Out:
# _layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_138 (Bat (None, 256)               1024
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 6s 114us/step - loss: 2.2944 - accuracy: 0.2381 - val_loss: 2.1915 - val_accuracy: 0.2121
# Epoch 2/25
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.9265 - accuracy: 0.3355 - val_loss: 2.0647 - val_accuracy: 0.2734
# Epoch 3/25
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.7885 - accuracy: 0.3780 - val_loss: 1.9166 - val_accuracy: 0.3314
# Epoch 4/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.7014 - accuracy: 0.4061 - val_loss: 1.8133 - val_accuracy: 0.3669
# Epoch 5/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.6396 - accuracy: 0.4288 - val_loss: 1.7432 - val_accuracy: 0.3900
# Epoch 6/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.5906 - accuracy: 0.4457 - val_loss: 1.6785 - val_accuracy: 0.4128
# Epoch 7/25
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.5506 - accuracy: 0.4596 - val_loss: 1.6591 - val_accuracy: 0.4144
# Epoch 8/25
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.5159 - accuracy: 0.4724 - val_loss: 1.6216 - val_accuracy: 0.4273
# Epoch 9/25
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.4824 - accuracy: 0.4830 - val_loss: 1.5994 - val_accuracy: 0.4392
# Epoch 10/25
# 50000/50000 [==============================] - 6s 115us/step - loss: 1.4551 - accuracy: 0.4945 - val_loss: 1.5832 - val_accuracy: 0.4427
# Epoch 11/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.4299 - accuracy: 0.5017 - val_loss: 1.5667 - val_accuracy: 0.4503
# Epoch 12/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.4053 - accuracy: 0.5121 - val_loss: 1.5771 - val_accuracy: 0.4480
# Epoch 13/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.3844 - accuracy: 0.5191 - val_loss: 1.5445 - val_accuracy: 0.4572
# Epoch 14/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.3644 - accuracy: 0.5262 - val_loss: 1.5368 - val_accuracy: 0.4624
# Epoch 15/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.3437 - accuracy: 0.5339 - val_loss: 1.5340 - val_accuracy: 0.4629
# Epoch 16/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.3258 - accuracy: 0.5415 - val_loss: 1.5358 - val_accuracy: 0.4632
# Epoch 17/25
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.3084 - accuracy: 0.5492 - val_loss: 1.5316 - val_accuracy: 0.4681
# Epoch 18/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.2917 - accuracy: 0.5552 - val_loss: 1.5263 - val_accuracy: 0.4674
# Epoch 19/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.2751 - accuracy: 0.5598 - val_loss: 1.5141 - val_accuracy: 0.4723
# Epoch 20/25
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.2597 - accuracy: 0.5658 - val_loss: 1.5055 - val_accuracy: 0.4739
# Epoch 21/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.2443 - accuracy: 0.5723 - val_loss: 1.5016 - val_accuracy: 0.4728
# Epoch 22/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.2316 - accuracy: 0.5751 - val_loss: 1.4979 - val_accuracy: 0.4792
# Epoch 23/25
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.2162 - accuracy: 0.5829 - val_loss: 1.5050 - val_accuracy: 0.4765
# Epoch 24/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.2031 - accuracy: 0.5868 - val_loss: 1.4947 - val_accuracy: 0.4823
# Epoch 25/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.1900 - accuracy: 0.5928 - val_loss: 1.4912 - val_accuracy: 0.4819
# Numbers of exp: 45, reduce_factor: 0.80, reduce_patient: 3
# Model: "model_47"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_47 (InputLayer)        (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               786688
# _________________________________________________________________
# batch_normalization_139 (Bat (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_140 (Bat (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_141 (Bat (None, 256)               1024
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 6s 112us/step - loss: 2.2999 - accuracy: 0.2370 - val_loss: 2.1991 - val_accuracy: 0.2254
# Epoch 2/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.9272 - accuracy: 0.3346 - val_loss: 2.0932 - val_accuracy: 0.2689
# Epoch 3/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.7889 - accuracy: 0.3773 - val_loss: 1.9791 - val_accuracy: 0.3116
# Epoch 4/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.7066 - accuracy: 0.4050 - val_loss: 1.8487 - val_accuracy: 0.3559
# Epoch 5/25
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.6453 - accuracy: 0.4272 - val_loss: 1.7448 - val_accuracy: 0.3881
# Epoch 6/25
# 50000/50000 [==============================] - 6s 111us/step - loss: 1.5959 - accuracy: 0.4427 - val_loss: 1.6917 - val_accuracy: 0.4038
# Epoch 7/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.5543 - accuracy: 0.4587 - val_loss: 1.6440 - val_accuracy: 0.4205
# Epoch 8/25
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.5188 - accuracy: 0.4695 - val_loss: 1.6146 - val_accuracy: 0.4325
# Epoch 9/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.4891 - accuracy: 0.4817 - val_loss: 1.6062 - val_accuracy: 0.4293
# Epoch 10/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.4606 - accuracy: 0.4923 - val_loss: 1.5971 - val_accuracy: 0.4339
# Epoch 11/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.4345 - accuracy: 0.5012 - val_loss: 1.5762 - val_accuracy: 0.4450
# Epoch 12/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.4115 - accuracy: 0.5080 - val_loss: 1.5801 - val_accuracy: 0.4430
# Epoch 13/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.3901 - accuracy: 0.5163 - val_loss: 1.5571 - val_accuracy: 0.4563
# Epoch 14/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.3701 - accuracy: 0.5240 - val_loss: 1.5473 - val_accuracy: 0.4565
# Epoch 15/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.3509 - accuracy: 0.5311 - val_loss: 1.5454 - val_accuracy: 0.4537
# Epoch 16/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.3330 - accuracy: 0.5358 - val_loss: 1.5421 - val_accuracy: 0.4603
# Epoch 17/25
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.3160 - accuracy: 0.5439 - val_loss: 1.5382 - val_accuracy: 0.4632
# Epoch 18/25
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.2992 - accuracy: 0.5501 - val_loss: 1.5264 - val_accuracy: 0.4695
# Epoch 19/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.2834 - accuracy: 0.5575 - val_loss: 1.5223 - val_accuracy: 0.4640
# Epoch 20/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.2679 - accuracy: 0.5620 - val_loss: 1.5401 - val_accuracy: 0.4619
# Epoch 21/25
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.2540 - accuracy: 0.5664 - val_loss: 1.5150 - val_accuracy: 0.4679
# Epoch 22/25
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.2403 - accuracy: 0.5719 - val_loss: 1.5289 - val_accuracy: 0.4688
# Epoch 23/25
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.2260 - accuracy: 0.5783 - val_loss: 1.5010 - val_accuracy: 0.4722
# Epoch 24/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.2131 - accuracy: 0.5825 - val_loss: 1.5083 - val_accuracy: 0.4713
# Epoch 25/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.2006 - accuracy: 0.5882 - val_loss: 1.5014 - val_accuracy: 0.4803
# Numbers of exp: 46, reduce_factor: 0.80, reduce_patient: 5
# Model: "model_48"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_48 (InputLayer)        (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               786688
# _________________________________________________________________
# batch_normalization_142 (Bat (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_143 (Bat (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_144 (Bat (None, 256)               1024
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 2.3632 - accuracy: 0.2321 - val_loss: 2.2075 - val_accuracy: 0.1573
# Epoch 2/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.9796 - accuracy: 0.3234 - val_loss: 2.0999 - val_accuracy: 0.2411
# Epoch 3/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.8304 - accuracy: 0.3683 - val_loss: 1.9615 - val_accuracy: 0.3148
# Epoch 4/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.7381 - accuracy: 0.3973 - val_loss: 1.8405 - val_accuracy: 0.3584
# Epoch 5/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.6705 - accuracy: 0.4177 - val_loss: 1.7674 - val_accuracy: 0.3768
# Epoch 6/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.6167 - accuracy: 0.4346 - val_loss: 1.7019 - val_accuracy: 0.3997
# Epoch 7/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.5741 - accuracy: 0.4501 - val_loss: 1.6474 - val_accuracy: 0.4237
# Epoch 8/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.5342 - accuracy: 0.4638 - val_loss: 1.6254 - val_accuracy: 0.4249
# Epoch 9/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.5024 - accuracy: 0.4746 - val_loss: 1.5999 - val_accuracy: 0.4373
# Epoch 10/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.4728 - accuracy: 0.4841 - val_loss: 1.5962 - val_accuracy: 0.4376
# Epoch 11/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.4460 - accuracy: 0.4946 - val_loss: 1.5775 - val_accuracy: 0.4485
# Epoch 12/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.4224 - accuracy: 0.5034 - val_loss: 1.5706 - val_accuracy: 0.4460
# Epoch 13/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.4000 - accuracy: 0.5120 - val_loss: 1.5599 - val_accuracy: 0.4501
# Epoch 14/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.3781 - accuracy: 0.5185 - val_loss: 1.5654 - val_accuracy: 0.4501
# Epoch 15/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.3588 - accuracy: 0.5279 - val_loss: 1.5539 - val_accuracy: 0.4527
# Epoch 16/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.3391 - accuracy: 0.5351 - val_loss: 1.5378 - val_accuracy: 0.4594
# Epoch 17/25
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.3214 - accuracy: 0.5394 - val_loss: 1.5406 - val_accuracy: 0.4584
# Epoch 18/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.3031 - accuracy: 0.5480 - val_loss: 1.5411 - val_accuracy: 0.4587
# Epoch 19/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.2882 - accuracy: 0.5526 - val_loss: 1.5236 - val_accuracy: 0.4655
# Epoch 20/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.2726 - accuracy: 0.5601 - val_loss: 1.5207 - val_accuracy: 0.4609
# Epoch 21/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.2567 - accuracy: 0.5662 - val_loss: 1.5118 - val_accuracy: 0.4708
# Epoch 22/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.2425 - accuracy: 0.5702 - val_loss: 1.5247 - val_accuracy: 0.4631
# Epoch 23/25
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.2286 - accuracy: 0.5762 - val_loss: 1.5213 - val_accuracy: 0.4674
# Epoch 24/25
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.2146 - accuracy: 0.5810 - val_loss: 1.5082 - val_accuracy: 0.4647
# Epoch 25/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.2018 - accuracy: 0.5862 - val_loss: 1.5022 - val_accuracy: 0.4732
# Numbers of exp: 47, reduce_factor: 0.80, reduce_patient: 10
# Model: "model_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_49 (InputLayer)        (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               786688
# _________________________________________________________________
# batch_normalization_145 (Bat (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_146 (Bat (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_147 (Bat (None, 256)               1024
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 6s 111us/step - loss: 2.2633 - accuracy: 0.2511 - val_loss: 2.1971 - val_accuracy: 0.1971
# Epoch 2/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.9141 - accuracy: 0.3438 - val_loss: 2.0782 - val_accuracy: 0.2508
# Epoch 3/25
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.7813 - accuracy: 0.3850 - val_loss: 1.9448 - val_accuracy: 0.3167
# Epoch 4/25
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.6977 - accuracy: 0.4105 - val_loss: 1.8240 - val_accuracy: 0.3560
# Epoch 5/25
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.6378 - accuracy: 0.4309 - val_loss: 1.7322 - val_accuracy: 0.3915
# Epoch 6/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.5889 - accuracy: 0.4465 - val_loss: 1.6849 - val_accuracy: 0.4018
# Epoch 7/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.5486 - accuracy: 0.4592 - val_loss: 1.6392 - val_accuracy: 0.4183
# Epoch 8/25
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.5136 - accuracy: 0.4714 - val_loss: 1.6184 - val_accuracy: 0.4277
# Epoch 9/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.4820 - accuracy: 0.4828 - val_loss: 1.5928 - val_accuracy: 0.4331
# Epoch 10/25
# 50000/50000 [==============================] - 6s 113us/step - loss: 1.4541 - accuracy: 0.4925 - val_loss: 1.5827 - val_accuracy: 0.4417
# Epoch 11/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.4301 - accuracy: 0.5005 - val_loss: 1.5648 - val_accuracy: 0.4454
# Epoch 12/25
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.4062 - accuracy: 0.5101 - val_loss: 1.5756 - val_accuracy: 0.4484
# Epoch 13/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.3845 - accuracy: 0.5171 - val_loss: 1.5591 - val_accuracy: 0.4510
# Epoch 14/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.3647 - accuracy: 0.5258 - val_loss: 1.5513 - val_accuracy: 0.4580
# Epoch 15/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.3446 - accuracy: 0.5330 - val_loss: 1.5491 - val_accuracy: 0.4556
# Epoch 16/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.3262 - accuracy: 0.5397 - val_loss: 1.5394 - val_accuracy: 0.4616
# Epoch 17/25
# 50000/50000 [==============================] - 6s 117us/step - loss: 1.3091 - accuracy: 0.5469 - val_loss: 1.5325 - val_accuracy: 0.4605
# Epoch 18/25
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.2923 - accuracy: 0.5516 - val_loss: 1.5144 - val_accuracy: 0.4660
# Epoch 19/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.2766 - accuracy: 0.5586 - val_loss: 1.5161 - val_accuracy: 0.4661
# Epoch 20/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.2629 - accuracy: 0.5637 - val_loss: 1.5187 - val_accuracy: 0.4624
# Epoch 21/25
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.2464 - accuracy: 0.5680 - val_loss: 1.5110 - val_accuracy: 0.4753
# Epoch 22/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.2328 - accuracy: 0.5748 - val_loss: 1.5043 - val_accuracy: 0.4723
# Epoch 23/25
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.2198 - accuracy: 0.5806 - val_loss: 1.5067 - val_accuracy: 0.4701
# Epoch 24/25
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.2063 - accuracy: 0.5868 - val_loss: 1.4957 - val_accuracy: 0.4713
# Epoch 25/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.1928 - accuracy: 0.5902 - val_loss: 1.5127 - val_accuracy: 0.4731

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = len(results.keys())

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback

# Record_fp_tp
class Record_tp_tn(Callback):
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ['val_auc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
        for i in record_items:
            if i in record_items:
                if i not in self.params['metrics']:
                    self.params['metrics'].append(i)
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] > thres) * 1
        val_tp = sum(y_true*y_pred)
        val_tn = sum((y_true==0) & (y_pred==0))
        
        logs["val_tp"] = val_tp
        logs["val_tn"] = val_tn
rec_tptn = Record_tp_tn()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            validation_data=(x_test, y_test),
            shuffle=True,
            callbacks=[rec_tptn])

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 6s 111us/step - loss: 2.2089 - accuracy: 0.2674 - val_loss: 2.1426 - val_accuracy: 0.1745
# Epoch 2/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.7445 - accuracy: 0.3922 - val_loss: 1.9989 - val_accuracy: 0.2735
# Epoch 3/25
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.6178 - accuracy: 0.4361 - val_loss: 1.8511 - val_accuracy: 0.3449
# Epoch 4/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.5433 - accuracy: 0.4613 - val_loss: 1.7471 - val_accuracy: 0.3937
# Epoch 5/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.4914 - accuracy: 0.4801 - val_loss: 1.6514 - val_accuracy: 0.4180
# Epoch 6/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.4457 - accuracy: 0.4953 - val_loss: 1.5879 - val_accuracy: 0.4427
# Epoch 7/25
# 50000/50000 [==============================] - 6s 115us/step - loss: 1.4061 - accuracy: 0.5096 - val_loss: 1.5576 - val_accuracy: 0.4504
# Epoch 8/25
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.3708 - accuracy: 0.5219 - val_loss: 1.5389 - val_accuracy: 0.4577
# Epoch 9/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.3384 - accuracy: 0.5348 - val_loss: 1.5162 - val_accuracy: 0.4650
# Epoch 10/25
# 50000/50000 [==============================] - 5s 98us/step - loss: 1.3094 - accuracy: 0.5448 - val_loss: 1.5021 - val_accuracy: 0.4700
# Epoch 11/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.2798 - accuracy: 0.5560 - val_loss: 1.4989 - val_accuracy: 0.4749
# Epoch 12/25
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.2519 - accuracy: 0.5656 - val_loss: 1.4812 - val_accuracy: 0.4772
# Epoch 13/25
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.2261 - accuracy: 0.5762 - val_loss: 1.4860 - val_accuracy: 0.4793
# Epoch 14/25
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.2011 - accuracy: 0.5845 - val_loss: 1.4800 - val_accuracy: 0.4816
# Epoch 15/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.1765 - accuracy: 0.5950 - val_loss: 1.4760 - val_accuracy: 0.4875
# Epoch 16/25
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.1517 - accuracy: 0.6027 - val_loss: 1.4676 - val_accuracy: 0.4871
# Epoch 17/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.1304 - accuracy: 0.6124 - val_loss: 1.4725 - val_accuracy: 0.4876
# Epoch 18/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.1066 - accuracy: 0.6207 - val_loss: 1.4821 - val_accuracy: 0.4866
# Epoch 19/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.0834 - accuracy: 0.6288 - val_loss: 1.4685 - val_accuracy: 0.4914
# Epoch 20/25
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.0610 - accuracy: 0.6382 - val_loss: 1.4715 - val_accuracy: 0.4912
# Epoch 21/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.0399 - accuracy: 0.6446 - val_loss: 1.4705 - val_accuracy: 0.4936
# Epoch 22/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.0188 - accuracy: 0.6534 - val_loss: 1.4761 - val_accuracy: 0.4916
# Epoch 23/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.9994 - accuracy: 0.6617 - val_loss: 1.4808 - val_accuracy: 0.4896
# Epoch 24/25
# 50000/50000 [==============================] - 5s 108us/step - loss: 0.9786 - accuracy: 0.6702 - val_loss: 1.4784 - val_accuracy: 0.4925
# Epoch 25/25
# 50000/50000 [==============================] - 5s 108us/step - loss: 0.9569 - accuracy: 0.6788 - val_loss: 1.4723 - val_accuracy: 0.4943

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()

# %% [markdown]
# ## Work
# 1. 請自行定義一個 loss function, 為 0.3 * focal loss + 0.7 cross-entropy，訓練並比較結果

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)

    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units,
                                activation='relu',
                                name='hidden_layer'+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units,
                                activation='relu',
                                name='hidden_layer'+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation='softmax', name='output')(x)

    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
import tensorflow as tf
import keras.backend as K

"""Code Here
撰寫一個 loss function, 使其可以結合 focal loss 與 crossentropy loss
"""
def combined_loss(gamma=2., alpha=4., ce_weights=0.7, fcl_weights=0.3):
    gamma = float(gamma)
    alpha = float(alpha)
    def CE_focal_loss(y_true, y_pred):
        """Focal loss for multi-classification
        FL(p_t)=-alpha(1-p_t)^{gamma}ln(p_t)
        """
        epsilon = 1e-8
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)

        model_out = tf.add(y_pred, epsilon)
        ce = tf.multiply(y_true, -tf.math.log(model_out))
        weight = tf.multiply(y_true, tf.pow(tf.subtract(1., model_out), gamma))
        fl = tf.multiply(alpha, tf.multiply(weight, ce))
        reduced_fl = tf.reduce_max(fl, axis=1)
        
        ce_loss = keras.losses.categorical_crossentropy(y_true, y_pred)
        return (ce_weights*ce_loss) + (fcl_weights*tf.reduce_mean(reduced_fl) )
    return CE_focal_loss

ce_weights_list = [0., 0.3, 0.5, 0.7, 1]

# %%
import itertools
results = {}

for i, ce_w in enumerate(ce_weights_list):
    print("Numbers of exp: %i, ce_weight: %.2f" % (i, ce_w))

    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    """Code Here
    將自定義的 loss function 加入模型
    """
    model.compile(loss=combined_loss(ce_weights=ce_w, fcl_weights=1.-ce_w), 
                  metrics=["accuracy"], optimizer=optimizer)
    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True
             )
    
    # Collect results
    exp_name_tag = ("exp-%s" % (i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["accuracy"],
                             'valid-acc': model.history.history["val_accuracy"]}
# Out:
# ____________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 6s 112us/step - loss: 5.0317 - accuracy: 0.3162 - val_loss: 5.2624 - val_accuracy: 0.2210
# Epoch 2/25
# 50000/50000 [==============================] - 5s 109us/step - loss: 3.6081 - accuracy: 0.4355 - val_loss: 4.4070 - val_accuracy: 0.3329
# Epoch 3/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 3.2772 - accuracy: 0.4775 - val_loss: 3.9739 - val_accuracy: 0.4079
# Epoch 4/25
# 50000/50000 [==============================] - 5s 102us/step - loss: 3.0677 - accuracy: 0.5049 - val_loss: 3.6245 - val_accuracy: 0.4477
# Epoch 5/25
# 50000/50000 [==============================] - 5s 110us/step - loss: 2.9058 - accuracy: 0.5252 - val_loss: 3.4477 - val_accuracy: 0.4610
# Epoch 6/25
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.7639 - accuracy: 0.5432 - val_loss: 3.2926 - val_accuracy: 0.4746
# Epoch 7/25
# 50000/50000 [==============================] - 5s 107us/step - loss: 2.6343 - accuracy: 0.5609 - val_loss: 3.3048 - val_accuracy: 0.4680
# Epoch 8/25
# 50000/50000 [==============================] - 5s 109us/step - loss: 2.5250 - accuracy: 0.5761 - val_loss: 3.3035 - val_accuracy: 0.4672
# Epoch 9/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 2.4018 - accuracy: 0.5913 - val_loss: 3.1754 - val_accuracy: 0.4794
# Epoch 10/25
# 50000/50000 [==============================] - 5s 107us/step - loss: 2.3036 - accuracy: 0.6057 - val_loss: 3.3598 - val_accuracy: 0.4662
# Epoch 11/25
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.2010 - accuracy: 0.6214 - val_loss: 3.1983 - val_accuracy: 0.4866
# Epoch 12/25
# 50000/50000 [==============================] - 6s 110us/step - loss: 2.1053 - accuracy: 0.6318 - val_loss: 3.1751 - val_accuracy: 0.4917
# Epoch 13/25
# 50000/50000 [==============================] - 5s 104us/step - loss: 2.0081 - accuracy: 0.6487 - val_loss: 3.1620 - val_accuracy: 0.4876
# Epoch 14/25
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.9171 - accuracy: 0.6610 - val_loss: 3.2948 - val_accuracy: 0.4848
# Epoch 15/25
# 50000/50000 [==============================] - 6s 115us/step - loss: 1.8324 - accuracy: 0.6745 - val_loss: 3.2148 - val_accuracy: 0.4890
# Epoch 16/25
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.7409 - accuracy: 0.6889 - val_loss: 3.2958 - val_accuracy: 0.4860
# Epoch 17/25
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.6459 - accuracy: 0.7015 - val_loss: 3.3008 - val_accuracy: 0.4834
# Epoch 18/25
# 50000/50000 [==============================] - 6s 117us/step - loss: 1.5681 - accuracy: 0.7136 - val_loss: 3.2972 - val_accuracy: 0.4944
# Epoch 19/25
# 50000/50000 [==============================] - 7s 131us/step - loss: 1.4852 - accuracy: 0.7290 - val_loss: 3.3964 - val_accuracy: 0.4854
# Epoch 20/25
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.4116 - accuracy: 0.7407 - val_loss: 3.5220 - val_accuracy: 0.4712
# Epoch 21/25
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.3347 - accuracy: 0.7516 - val_loss: 3.3776 - val_accuracy: 0.4925
# Epoch 22/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.2637 - accuracy: 0.7645 - val_loss: 3.4661 - val_accuracy: 0.4904
# Epoch 23/25
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.1869 - accuracy: 0.7768 - val_loss: 3.6259 - val_accuracy: 0.4784
# Epoch 24/25
# 50000/50000 [==============================] - 6s 113us/step - loss: 1.1190 - accuracy: 0.7904 - val_loss: 3.5896 - val_accuracy: 0.4924
# Epoch 25/25
# 50000/50000 [==============================] - 6s 120us/step - loss: 1.0451 - accuracy: 0.8046 - val_loss: 3.6861 - val_accuracy: 0.4791
# Numbers of exp: 2, ce_weight: 0.50
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 6s 113us/step - loss: 4.1972 - accuracy: 0.3121 - val_loss: 4.3057 - val_accuracy: 0.2100
# Epoch 2/25
# 50000/50000 [==============================] - 5s 105us/step - loss: 3.0922 - accuracy: 0.4320 - val_loss: 3.7470 - val_accuracy: 0.3225
# Epoch 3/25
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.8255 - accuracy: 0.4718 - val_loss: 3.3751 - val_accuracy: 0.3874
# Epoch 4/25
# 50000/50000 [==============================] - 5s 106us/step - loss: 2.6514 - accuracy: 0.4974 - val_loss: 3.1469 - val_accuracy: 0.4186
# Epoch 5/25
# 50000/50000 [==============================] - 6s 111us/step - loss: 2.5209 - accuracy: 0.5215 - val_loss: 2.9903 - val_accuracy: 0.4356
# Epoch 6/25
# 50000/50000 [==============================] - 6s 112us/step - loss: 2.4131 - accuracy: 0.5384 - val_loss: 2.8576 - val_accuracy: 0.4599
# Epoch 7/25
# 50000/50000 [==============================] - 6s 112us/step - loss: 2.3086 - accuracy: 0.5525 - val_loss: 2.8462 - val_accuracy: 0.4598
# Epoch 8/25
# 50000/50000 [==============================] - 6s 111us/step - loss: 2.2177 - accuracy: 0.5680 - val_loss: 2.7547 - val_accuracy: 0.4686
# Epoch 9/25
# 50000/50000 [==============================] - 5s 108us/step - loss: 2.1300 - accuracy: 0.5839 - val_loss: 2.7641 - val_accuracy: 0.4734
# Epoch 10/25
# 50000/50000 [==============================] - 5s 109us/step - loss: 2.0463 - accuracy: 0.5979 - val_loss: 2.6882 - val_accuracy: 0.4909
# Epoch 11/25
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.9657 - accuracy: 0.6106 - val_loss: 2.7418 - val_accuracy: 0.4792
# Epoch 12/25
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.8923 - accuracy: 0.6224 - val_loss: 2.7061 - val_accuracy: 0.4848
# Epoch 13/25
# 50000/50000 [==============================] - 6s 110us/step - loss: 1.8216 - accuracy: 0.6356 - val_loss: 2.7432 - val_accuracy: 0.4803
# Epoch 14/25
# 50000/50000 [==============================] - 6s 116us/step - loss: 1.7455 - accuracy: 0.6490 - val_loss: 2.7185 - val_accuracy: 0.4869
# Epoch 15/25
# 50000/50000 [==============================] - 6s 114us/step - loss: 1.6742 - accuracy: 0.6604 - val_loss: 2.7616 - val_accuracy: 0.4816
# Epoch 16/25
# 50000/50000 [==============================] - 6s 114us/step - loss: 1.6030 - accuracy: 0.6754 - val_loss: 2.7415 - val_accuracy: 0.4880
# Epoch 17/25
# 50000/50000 [==============================] - 6s 113us/step - loss: 1.5368 - accuracy: 0.6858 - val_loss: 2.8064 - val_accuracy: 0.4839
# Epoch 18/25
# 50000/50000 [==============================] - 6s 119us/step - loss: 1.4752 - accuracy: 0.6949 - val_loss: 2.8313 - val_accuracy: 0.4822
# Epoch 19/25
# 50000/50000 [==============================] - 6s 126us/step - loss: 1.4116 - accuracy: 0.7100 - val_loss: 2.7635 - val_accuracy: 0.4936
# Epoch 20/25
# 50000/50000 [==============================] - 6s 122us/step - loss: 1.3443 - accuracy: 0.7232 - val_loss: 2.9078 - val_accuracy: 0.4799
# Epoch 21/25
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.2874 - accuracy: 0.7313 - val_loss: 2.8682 - val_accuracy: 0.4823
# Epoch 22/25
# 50000/50000 [==============================] - 6s 116us/step - loss: 1.2256 - accuracy: 0.7462 - val_loss: 2.9044 - val_accuracy: 0.4804
# Epoch 23/25
# 50000/50000 [==============================] - 6s 114us/step - loss: 1.1697 - accuracy: 0.7567 - val_loss: 2.9352 - val_accuracy: 0.4840
# Epoch 24/25
# 50000/50000 [==============================] - 6s 116us/step - loss: 1.1103 - accuracy: 0.7698 - val_loss: 2.8602 - val_accuracy: 0.5004
# Epoch 25/25
# 50000/50000 [==============================] - 6s 116us/step - loss: 1.0518 - accuracy: 0.7821 - val_loss: 2.9533 - val_accuracy: 0.4860
# Numbers of exp: 3, ce_weight: 0.70
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 6s 123us/step - loss: 3.4414 - accuracy: 0.2991 - val_loss: 3.3921 - val_accuracy: 0.2287
# Epoch 2/25
# 50000/50000 [==============================] - 6s 124us/step - loss: 2.5642 - accuracy: 0.4202 - val_loss: 3.0841 - val_accuracy: 0.2991
# Epoch 3/25
# 50000/50000 [==============================] - 6s 122us/step - loss: 2.3502 - accuracy: 0.4609 - val_loss: 2.7326 - val_accuracy: 0.3957
# Epoch 4/25
# 50000/50000 [==============================] - 7s 135us/step - loss: 2.2165 - accuracy: 0.4882 - val_loss: 2.5437 - val_accuracy: 0.4281
# Epoch 5/25
# 50000/50000 [==============================] - 7s 133us/step - loss: 2.1163 - accuracy: 0.5085 - val_loss: 2.4110 - val_accuracy: 0.4399
# Epoch 6/25
# 50000/50000 [==============================] - 7s 137us/step - loss: 2.0339 - accuracy: 0.5262 - val_loss: 2.3368 - val_accuracy: 0.4501
# Epoch 7/25
# 50000/50000 [==============================] - 7s 138us/step - loss: 1.9548 - accuracy: 0.5416 - val_loss: 2.2662 - val_accuracy: 0.4739
# Epoch 8/25
# 50000/50000 [==============================] - 7s 142us/step - loss: 1.8876 - accuracy: 0.5555 - val_loss: 2.2112 - val_accuracy: 0.4845
# Epoch 9/25
# 50000/50000 [==============================] - 6s 130us/step - loss: 1.8245 - accuracy: 0.5671 - val_loss: 2.2035 - val_accuracy: 0.4811
# Epoch 10/25
# 50000/50000 [==============================] - 7s 144us/step - loss: 1.7679 - accuracy: 0.5805 - val_loss: 2.2059 - val_accuracy: 0.4857
# Epoch 11/25
# 50000/50000 [==============================] - 7s 142us/step - loss: 1.7097 - accuracy: 0.5917 - val_loss: 2.2119 - val_accuracy: 0.4823
# Epoch 12/25
# 50000/50000 [==============================] - 7s 132us/step - loss: 1.6574 - accuracy: 0.6050 - val_loss: 2.1956 - val_accuracy: 0.4864
# Epoch 13/25
# 50000/50000 [==============================] - 7s 137us/step - loss: 1.6070 - accuracy: 0.6141 - val_loss: 2.1705 - val_accuracy: 0.4965
# Epoch 14/25
# 50000/50000 [==============================] - 8s 155us/step - loss: 1.5529 - accuracy: 0.6275 - val_loss: 2.1672 - val_accuracy: 0.4952
# Epoch 15/25
# 50000/50000 [==============================] - 8s 157us/step - loss: 1.5041 - accuracy: 0.6384 - val_loss: 2.1721 - val_accuracy: 0.4987
# Epoch 16/25
# 50000/50000 [==============================] - 7s 145us/step - loss: 1.4523 - accuracy: 0.6518 - val_loss: 2.1928 - val_accuracy: 0.4948
# Epoch 17/25
# 50000/50000 [==============================] - 7s 144us/step - loss: 1.4084 - accuracy: 0.6602 - val_loss: 2.1825 - val_accuracy: 0.4975
# Epoch 18/25
# 50000/50000 [==============================] - 8s 157us/step - loss: 1.3627 - accuracy: 0.6700 - val_loss: 2.2005 - val_accuracy: 0.4992
# Epoch 19/25
# 50000/50000 [==============================] - 7s 131us/step - loss: 1.3149 - accuracy: 0.6819 - val_loss: 2.2280 - val_accuracy: 0.4963
# Epoch 20/25
# 50000/50000 [==============================] - 7s 130us/step - loss: 1.2654 - accuracy: 0.6934 - val_loss: 2.2315 - val_accuracy: 0.4907
# Epoch 21/25
# 50000/50000 [==============================] - 7s 130us/step - loss: 1.2243 - accuracy: 0.7036 - val_loss: 2.2503 - val_accuracy: 0.4986
# Epoch 22/25
# 50000/50000 [==============================] - 8s 152us/step - loss: 1.1805 - accuracy: 0.7124 - val_loss: 2.2329 - val_accuracy: 0.4994
# Epoch 23/25
# 50000/50000 [==============================] - 7s 144us/step - loss: 1.1352 - accuracy: 0.7279 - val_loss: 2.2381 - val_accuracy: 0.4986
# Epoch 24/25
# 50000/50000 [==============================] - 7s 143us/step - loss: 1.0903 - accuracy: 0.7403 - val_loss: 2.3011 - val_accuracy: 0.4929
# Epoch 25/25
# 50000/50000 [==============================] - 8s 151us/step - loss: 1.0485 - accuracy: 0.7467 - val_loss: 2.3122 - val_accuracy: 0.4906
# Numbers of exp: 4, ce_weight: 1.00
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 6s 130us/step - loss: 2.2169 - accuracy: 0.2716 - val_loss: 2.1544 - val_accuracy: 0.2005
# Epoch 2/25
# 50000/50000 [==============================] - 6s 124us/step - loss: 1.7462 - accuracy: 0.3945 - val_loss: 1.9537 - val_accuracy: 0.3137
# Epoch 3/25
# 50000/50000 [==============================] - 6s 123us/step - loss: 1.6154 - accuracy: 0.4366 - val_loss: 1.8233 - val_accuracy: 0.3685
# Epoch 4/25
# 50000/50000 [==============================] - 6s 122us/step - loss: 1.5400 - accuracy: 0.4634 - val_loss: 1.6978 - val_accuracy: 0.4187
# Epoch 5/25
# 50000/50000 [==============================] - 7s 130us/step - loss: 1.4841 - accuracy: 0.4837 - val_loss: 1.6307 - val_accuracy: 0.4348
# Epoch 6/25
# 50000/50000 [==============================] - 6s 122us/step - loss: 1.4406 - accuracy: 0.4993 - val_loss: 1.5750 - val_accuracy: 0.4544
# Epoch 7/25
# 50000/50000 [==============================] - 7s 137us/step - loss: 1.3997 - accuracy: 0.5134 - val_loss: 1.5514 - val_accuracy: 0.4597
# Epoch 8/25
# 50000/50000 [==============================] - 9s 178us/step - loss: 1.3635 - accuracy: 0.5268 - val_loss: 1.5132 - val_accuracy: 0.4692
# Epoch 9/25
# 50000/50000 [==============================] - 8s 166us/step - loss: 1.3304 - accuracy: 0.5363 - val_loss: 1.4981 - val_accuracy: 0.4745
# Epoch 10/25
# 50000/50000 [==============================] - 8s 158us/step - loss: 1.2997 - accuracy: 0.5484 - val_loss: 1.4816 - val_accuracy: 0.4785
# Epoch 11/25
# 50000/50000 [==============================] - 6s 120us/step - loss: 1.2734 - accuracy: 0.5583 - val_loss: 1.4721 - val_accuracy: 0.4837
# Epoch 12/25
# 50000/50000 [==============================] - 6s 119us/step - loss: 1.2438 - accuracy: 0.5679 - val_loss: 1.4610 - val_accuracy: 0.4890
# Epoch 13/25
# 50000/50000 [==============================] - 6s 119us/step - loss: 1.2212 - accuracy: 0.5763 - val_loss: 1.4693 - val_accuracy: 0.4825
# Epoch 14/25
# 50000/50000 [==============================] - 6s 114us/step - loss: 1.1940 - accuracy: 0.5866 - val_loss: 1.4499 - val_accuracy: 0.4938
# Epoch 15/25
# 50000/50000 [==============================] - 6s 116us/step - loss: 1.1717 - accuracy: 0.5967 - val_loss: 1.4460 - val_accuracy: 0.4910
# Epoch 16/25
# 50000/50000 [==============================] - 6s 115us/step - loss: 1.1469 - accuracy: 0.6053 - val_loss: 1.4390 - val_accuracy: 0.4965
# Epoch 17/25
# 50000/50000 [==============================] - 6s 120us/step - loss: 1.1254 - accuracy: 0.6123 - val_loss: 1.4594 - val_accuracy: 0.4905
# Epoch 18/25
# 50000/50000 [==============================] - 6s 116us/step - loss: 1.1036 - accuracy: 0.6208 - val_loss: 1.4371 - val_accuracy: 0.4935
# Epoch 19/25
# 50000/50000 [==============================] - 6s 123us/step - loss: 1.0807 - accuracy: 0.6282 - val_loss: 1.4428 - val_accuracy: 0.4976
# Epoch 20/25
# 50000/50000 [==============================] - 7s 142us/step - loss: 1.0586 - accuracy: 0.6370 - val_loss: 1.4404 - val_accuracy: 0.4926
# Epoch 21/25
# 50000/50000 [==============================] - 6s 129us/step - loss: 1.0373 - accuracy: 0.6467 - val_loss: 1.4431 - val_accuracy: 0.4957
# Epoch 22/25
# 50000/50000 [==============================] - 6s 120us/step - loss: 1.0151 - accuracy: 0.6558 - val_loss: 1.4421 - val_accuracy: 0.5010
# Epoch 23/25
# 50000/50000 [==============================] - 6s 128us/step - loss: 0.9955 - accuracy: 0.6623 - val_loss: 1.4428 - val_accuracy: 0.5007
# Epoch 24/25
# 50000/50000 [==============================] - 10s 209us/step - loss: 0.9757 - accuracy: 0.6715 - val_loss: 1.4489 - val_accuracy: 0.5001
# Epoch 25/25
# 50000/50000 [==============================] - 9s 184us/step - loss: 0.9561 - accuracy: 0.6788 - val_loss: 1.4512 - val_accuracy: 0.5000

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = len(results.keys())

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
